# %% [markdown]
# # Zhang et al. Comp
# From Zhang et al 2001, Eqn 8.
#
# \
# __USE SHIFT+ENTER ON CELL BELOW TO OPEN INTERACTIVE WIDGET__

# %%
from zhang_widget import run_zhang_app

run_zhang_app()
